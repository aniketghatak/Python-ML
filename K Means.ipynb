# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
x = [39, 51, 102, 41, 34, 109, 141 , 63, 104, 119]
y = [209, 194, 241, 167, 162, 248, 239, 218, 214, 208]

# %%
plt.scatter(x,y)
plt.show()

# %%
data=list(zip(x,y))
print(data)
# Out:
# [(39, 209), (51, 194), (102, 241), (41, 167), (34, 162), (109, 248), (141, 239), (63, 218), (104, 214), (119, 208)]

# %%
inertias=[]

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)
    
plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# #### We can see that the "elbow" (where the interia becomes more linear) on the graph above  is at K=2.
# #### We can then fit our K-means algorithm one more time and plot the different clusters assigned to the data:

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()
